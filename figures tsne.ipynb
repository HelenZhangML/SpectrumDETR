# %%
import sys
import importlib

sys.modules.pop("scripts.plot_representation_tsne", None)
importlib.invalidate_caches()

from scripts.plot_representation_tsne import plot_tsne_grid, plot_all_tsne_pairs

plot_tsne_grid()
plot_all_tsne_pairs()
# Out:
# Saved: figures_tsne_grid/tsne_3x3_column_legends.png
#
# === SkipAtom ===
# X: (1052, 1012)
# Saved: figures_clean_pairs_multi/skipatom__C-F_vs_C-Cl.png
# Saved: figures_clean_pairs_multi/skipatom__C-Cl_vs_C-Br.png
# Saved: figures_clean_pairs_multi/skipatom__O_ether__vs_O_carbonyl_.png
# Saved: figures_clean_pairs_multi/skipatom__N_amide__vs_N_aromatic_.png
# Saved: figures_clean_pairs_multi/skipatom__C_aromatic__vs_C_sp3_.png
# Saved: figures_clean_pairs_multi/skipatom__C_carbonyl__vs_O_carbonyl_.png
#
# === MatScholar ===
# X: (1052, 1012)
# Saved: figures_clean_pairs_multi/matscholar__C-F_vs_C-Cl.png
# Saved: figures_clean_pairs_multi/matscholar__C-Cl_vs_C-Br.png
# Saved: figures_clean_pairs_multi/matscholar__O_ether__vs_O_carbonyl_.png
# Saved: figures_clean_pairs_multi/matscholar__N_amide__vs_N_aromatic_.png
# Saved: figures_clean_pairs_multi/matscholar__C_aromatic__vs_C_sp3_.png
# Saved: figures_clean_pairs_multi/matscholar__C_carbonyl__vs_O_carbonyl_.png
#
# === SOAP ===
# ...
